# %% [markdown]
# ```text
#                     SUPERVISED LEARNING
#                               |
#           -----------------------------------------
#           |                                       |
#       REGRESSION                           CLASSIFICATION
#     (Predict Numbers)                   (Predict Categories)
#
#           |                                       |
#    Binary / Continuous /                 Binary / Multi-Class /
#       Multi-Output                          Multi-Label
#
#           |                                       |
#
#    Linear Regression                    Logistic Regression
#    KNN Regressor                        KNN Classifier
#    Decision Tree Regressor              Decision Tree Classifier
#    Random Forest Regressor              Random Forest Classifier
#    SVR                                  SVM
#                                         Naive Bayes
#
#                                         |
#                               ---------------------
#                               |                   |
#                            Binary            Multi-Class
#                           (0 or 1)          (0,1,2,3...)
#
#                        Logistic Regression
#                     (Sigmoid Function)
#
#                     Multinomial Logistic
#                     Regression (Softmax)
# ```

# %% [markdown]
# | Feature    | Linear Regression | Logistic Regression |
# | ---------- | ----------------- | ------------------- |
# | Purpose    | Predict number    | Predict category    |
# | Output     | Continuous value  | Class label         |
# | Example    | House Price       | Spam Detection      |
# | Formula    | Best fit line     | Sigmoid             |
# | Range      | Any value         | 0 to 1 probability  |
# | Evaluation | MAE/MSE/RMSE      | Accuracy/Log Loss   |
# | Prediction | Direct value      | Probability → Class |

# %% [markdown]
# # LINEAR REGRESSION WORKFLOW

# %% [markdown]
# ```text
# Collect Data
#       ↓
# Select X and y
#       ↓
# Train-Test Split
#       ↓
# Create LinearRegression Model
#       ↓
# model.fit()
#       ↓
# model.predict()
#       ↓
# Check Error (MAE/MSE/RMSE)
# ```

# %% [markdown]
# #  LOGISTIC REGRESSION WORKFLOW

# %% [markdown]
# ```text
# Collect Data
#       ↓
# Select X and y
#       ↓
# Train-Test Split
#       ↓
# Create LogisticRegression Model
#       ↓
# model.fit()
#       ↓
# predict_proba()
#       ↓
# predict()
#       ↓
# Check Accuracy
# ```

# %% [markdown]
# # PERFORMING LINEAR REGRESSION

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("canada.csv")
df
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
x = df[["year"]]
y = df[["per capita income (US$)"]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train ,x_test, y_train ,y_test = train_test_split(x,y, train_size=0.2 , random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y = model.predict(x_test)
y
# Out:
# array([[22705.59597862],
#        [33453.48840501],
#        [21809.93827642],
#        [37036.11921381],
#        [20018.62287202],
#        [30766.51529841],
#        [ 9270.73044564],
#        [15540.33436103],
#        [ 2105.46882804],
#        [20914.28057422],
#        [ 5688.09963684],
#        [ 1209.81112585],
#        [ 3896.78423244],
#        [34349.14610721],
#        [28079.54219182],
#        [10166.38814784],
#        [13749.01895663],
#        [37931.776916  ],
#        [11957.70355223],
#        [ 6583.75733904],
#        [12853.36125443],
#        [24496.91138302],
#        [27183.88448962],
#        [38827.4346182 ],
#        [-1477.16198075],
#        [26288.22678742],
#        [25392.56908522],
#        [ 3001.12653024],
#        [ 8375.07274344],
#        [28975.19989401],
#        [ -581.50427855],
#        [35244.80380941],
#        [17331.64976543],
#        [  314.15342365],
#        [29870.85759621],
#        [19122.96516983],
#        [31662.17300061],
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pred = model.predict([[2080]])
pred
# Out:
# array([[97045.18526114]])

# %%
df = pd.read_csv("BHK.csv")
df
# Out:
#     BHK     Price
# 0     1   3200000
# 1     1   3500000
# 2     1   3800000
# 3     1   4100000
# 4     1   4400000
# ..  ...       ...
# 94    4  26000000
# 95    4  26500000
# 96    4  27000000
# 97    4  27500000
# 98    4  28000000
#
# [99 rows x 2 columns]

# %%
X = df[["BHK"]]
y = df[["Price"]]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train ,X_test, y_train ,y_test = train_test_split(X,y, train_size=0.2 , random_state=42)

# %%
print(X.shape)
print(y.shape)

print(X_train.shape)
print(y_train.shape)

print(X_test.shape)
print(y_test.shape)
# Out:
# (99, 1)
# (99, 1)
# (19, 1)
# (19, 1)
# (80, 1)
# (80, 1)

# %%
model = LinearRegression()

# %%
model.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([[15781487.88927336],
#        [11046020.76124567],
#        [20516955.01730104],
#        [ 6310553.63321799],
#        [20516955.01730104],
#        [20516955.01730104],
#        [15781487.88927336],
#        [11046020.76124567],
#        [ 6310553.63321799],
#        [ 6310553.63321799],
#        [11046020.76124567],
#        [20516955.01730104],
#        [11046020.76124567],
#        [11046020.76124567],
#        [11046020.76124567],
#        [ 6310553.63321799],
#        [ 6310553.63321799],
#        [ 6310553.63321799],
#        [20516955.01730104],
#        [15781487.88927336],
#        [15781487.88927336],
#        [15781487.88927336],
#        [15781487.88927336],
#        [ 6310553.63321799],
#        [11046020.76124567],
#        [11046020.76124567],
#        [ 6310553.63321799],
#        [20516955.01730104],
#        [ 6310553.63321799],
#        [15781487.88927336],
#        [20516955.01730104],
#        [11046020.76124567],
#        [11046020.76124567],
# ...

# %%
pre= model.predict([[4]])
pre
# Out:
# array([[20516955.01730104]])

# %%
from sklearn.metrics import mean_absolute_error ,mean_squared_error,root_mean_squared_error , r2_score

# %%
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.7827958763605093

# %%
df = pd.read_csv("BHK.csv")

X = df['BHK']
y = df['Price']

plt.scatter(X, y)
plt.xlabel("BHK")
plt.ylabel("Price")
plt.title("BHK vs Price")
plt.show()

# %% [markdown]
# # PERFORMING KNN REGRESSION

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("BHK.csv")
df
# Out:
#     BHK     Price
# 0     1   3200000
# 1     1   3500000
# 2     1   3800000
# 3     1   4100000
# 4     1   4400000
# ..  ...       ...
# 94    4  26000000
# 95    4  26500000
# 96    4  27000000
# 97    4  27500000
# 98    4  28000000
#
# [99 rows x 2 columns]

# %%
X = df[['BHK']]
y = df['Price']

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)
X
# Out:
#     BHK
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# ..  ...
# 94    4
# 95    4
# 96    4
# 97    4
# 98    4
#
# [99 rows x 1 columns]

# %%
X_train , X_test ,y_train, y_test = train_test_split(X_scaled, y, test_size=0.2 , random_state=42)

# %%
model = KNeighborsRegressor(n_neighbors=3)

# %%
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
y_pred = model.predict(X_test)

# %%
score = r2_score(y_test, y_pred)
print(score)
# Out:
# 0.8087018819020727

# %% [markdown]
# # KNN WORKFLOW

# %% [markdown]
# ```text
# Dataset
#    ↓
# Scaling
#    ↓
# Train-Test Split
#    ↓
# KNeighborsRegressor()
#    ↓
# fit()
#    ↓
# predict()
#    ↓
# R² / MAE / RMSE
# ```

# %% [markdown]
# ```text
#          ┌───────────────────────┐
#          │   CHOOSE ALGORITHM    │
#          └──────────┬────────────┘
#                     │
#     ┌───────────────┼────────────────┐
#     │               │                │
#     ▼               ▼                ▼
#
# ┌────────────────┐ ┌─────────────────┐ ┌────────────────────┐
# │LINEAR REGRESSION│ │LOGISTIC REGRESSION│ │        KNN         │
# └───────┬────────┘ └────────┬────────┘ └─────────┬──────────┘
#         │                   │                    │
#         ▼                   ▼                    ▼
#
# ┌────────────────┐ ┌─────────────────┐ ┌────────────────────┐
# │IMPORT CHANGE   │ │IMPORT CHANGE    │ │IMPORT CHANGE       │
# │LinearRegression│ │LogisticRegression│ │KNeighborsClassifier│
# └───────┬────────┘ └────────┬────────┘ └─────────┬──────────┘
#         │                   │                    │
#         ▼                   ▼                    ▼
#
# ┌────────────────┐ ┌─────────────────┐ ┌────────────────────┐
# │MODEL CREATE    │ │MODEL CREATE     │ │MODEL CREATE        │
# │LinearRegression│ │LogisticRegression│ │KNN(k=5)            │
# └───────┬────────┘ └────────┬────────┘ └─────────┬──────────┘
#         │                   │                    │
#         │                   │             ★ CHANGE HAPPENS
#         │                   │             choose neighbors
#         │                   │             n_neighbors=5
#         ▼                   ▼                    ▼
#
# ┌────────────────┐ ┌─────────────────┐ ┌────────────────────┐
# │TRAIN MODEL     │ │TRAIN MODEL      │ │TRAIN MODEL         │
# │model.fit()     │ │model.fit()      │ │model.fit()         │
# └───────┬────────┘ └────────┬────────┘ └─────────┬──────────┘
#         │                   │                    │
#         ▼                   ▼                    ▼
#
# ┌────────────────┐ ┌─────────────────┐ ┌────────────────────┐
# │PREDICT         │ │PREDICT          │ │PREDICT             │
# │model.predict() │ │model.predict()  │ │model.predict()     │
# └───────┬────────┘ └────────┬────────┘ └─────────┬──────────┘
#         │                   │                    │
#         ▼                   ▼                    ▼
#
# ┌────────────────┐ ┌─────────────────┐ ┌────────────────────┐
# │OUTPUT NUMBER   │ │OUTPUT CATEGORY  │ │OUTPUT FROM         │
# │45.6            │ │YES / NO         │ │NEAREST POINTS      │
# └────────────────┘ └─────────────────┘ └────────────────────┘
# ```
